# %% [markdown]
# les produits avec le plus de retours
#
# Quel est le cycle de vie d'un vos produit ?
#
# Quels sont les problèmes que vous avez pu rencontrer ou que vous rencontrez actuellement ?
#
# Quels sont vos objectifs pour l'avenir ? (Agrandissement, etc.)
#
# Avec quelles entreprises travaillez vous ?
#
# Eclaircissement sur certaines variables : StockCode, Country et UnitePrice
#
# Problème de données manquantes et/ou incohérente
#
# ça c'est plus ou moins pour l'oral
#
# Maintenant on a 2 trucs à faire
#
# y en a un qui va lister toutes les informations manquantes et/ou incohérente et l'autre qui fait la masse de KPI
#
# Decrivez les différents poste dans votre entreprise

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv',encoding = "ISO-8859-1")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.corr()
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.001235    -0.00360
# UnitPrice  -0.001235   1.000000    -0.00456
# CustomerID -0.003600  -0.004560     1.00000

# %%
dfQ = df[df['Quantity'] <= -80995]
dfQ
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540422   C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 540422  12/9/2011 9:27       2.08     16446.0  United Kingdom

# %%
# Trier les données en fonction des ventes, du plus grand au plus petit
df.sort_values(by="Quantity", ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# ...          ...       ...                                  ...       ...
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225530    556691     23005         printing smudges/thrown away     -9600
# 225529    556690     23005         printing smudges/thrown away     -9600
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_sort = df.groupby('Description').sort_values(by='Quantity', ascending=False)
df_sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\adrie\PycharmProjects\MathData\maths_datascience\fil_rouge\math_datasciences\Projet_Adrien.ipynb Cellule 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adrie/PycharmProjects/MathData/maths_datascience/fil_rouge/math_datasciences/Projet_Adrien.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df_sort = df.groupby('Description').sort_values(by='Quantity', ascending=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/adrie/PycharmProjects/MathData/maths_datascience/fil_rouge/math_datasciences/Projet_Adrien.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df_sort
#
# File c:\Users\adrie\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
# ...

# %%
df_sort_by_quantity=df.groupby('Description').sum().sort_values(['Quantity'],ascending=False)
df_sort_by_quantity
# Out:
#                                    Quantity  UnitPrice  CustomerID
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847     173.39   7297844.0
# JUMBO BAG RED RETROSPOT               47363    5333.30  25396253.0
# ASSORTED COLOUR BIRD ORNAMENT         36381    2584.77  21602517.0
# POPCORN HOLDER                        36334     874.50  10688216.0
# PACK OF 72 RETROSPOT CAKE CASES       36039    1047.04  16309247.0
# ...                                     ...        ...         ...
# Damaged                               -7540       0.00         0.0
# Printing smudges/thrown away          -9058       0.00         0.0
# check                                -12030       0.00         0.0
# Unsaleable, destroyed.               -15644       0.00         0.0
# printing smudges/thrown away         -19200       0.00         0.0
#
# [4223 rows x 3 columns]

# %%
df_sort_customers_by_quantity=df.groupby('CustomerID').sum().sort_values(['Quantity'],ascending=False)
df_sort_customers_by_quantity
# Out:
#             Quantity  UnitPrice
# CustomerID
# 14646.0       196719    5400.21
# 12415.0        77242    2499.82
# 14911.0        77180   31060.66
# 17450.0        69029    3320.09
# 18102.0        64122    5159.73
# ...              ...        ...
# 16252.0         -158      67.10
# 16742.0         -189     472.65
# 14213.0         -244      24.45
# 15823.0         -283      85.19
# 16546.0         -303      53.03
#
# [4372 rows x 2 columns]
